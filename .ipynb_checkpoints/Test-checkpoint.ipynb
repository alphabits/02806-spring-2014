# %%
import pandas as pd
from matplotlib import pyplot as plt
import pymssql
import datetime

# %%
conn = pymssql.connect("37KG-PC", "WBDev", "123456", "WorkBox")

# %%
select_user_counts = """
    Select cast(cast(Info_CreatedAt as Date) as DateTime) as d, count(*) as cnt
    from UserProfile
    group by cast(Info_CreatedAt as Date)
"""
cursor = conn.cursor(as_dict=True)
cursor.execute(select_user_counts)
user_counts = [u for u in cursor]

# %%
user_counts = [u for u in user_counts if u["d"] > datetime.datetime(2000, 1, 1)]

# %%
user_counts
# Out:
# [{u'cnt': 25, u'd': datetime.datetime(2013, 7, 30, 0, 0)},
#  {u'cnt': 30, u'd': datetime.datetime(2013, 6, 14, 0, 0)},
#  {u'cnt': 46, u'd': datetime.datetime(2013, 10, 15, 0, 0)},
#  {u'cnt': 89, u'd': datetime.datetime(2014, 1, 29, 0, 0)},
#  {u'cnt': 36, u'd': datetime.datetime(2013, 5, 28, 0, 0)},
#  {u'cnt': 73, u'd': datetime.datetime(2013, 12, 17, 0, 0)},
#  {u'cnt': 64, u'd': datetime.datetime(2014, 2, 1, 0, 0)},
#  {u'cnt': 14, u'd': datetime.datetime(2013, 7, 27, 0, 0)},
#  {u'cnt': 23, u'd': datetime.datetime(2013, 8, 13, 0, 0)},
#  {u'cnt': 36, u'd': datetime.datetime(2013, 9, 28, 0, 0)},
#  {u'cnt': 67, u'd': datetime.datetime(2013, 6, 11, 0, 0)},
#  {u'cnt': 483, u'd': datetime.datetime(2013, 5, 2, 0, 0)},
#  {u'cnt': 45, u'd': datetime.datetime(2013, 11, 30, 0, 0)},
#  {u'cnt': 32, u'd': datetime.datetime(2013, 8, 19, 0, 0)},
#  {u'cnt': 81, u'd': datetime.datetime(2013, 11, 4, 0, 0)},
#  {u'cnt': 20, u'd': datetime.datetime(2013, 6, 17, 0, 0)},
#  {u'cnt': 27, u'd': datetime.datetime(2013, 8, 16, 0, 0)},
#  {u'cnt': 40, u'd': datetime.datetime(2013, 12, 20, 0, 0)},
#  {u'cnt': 30, u'd': datetime.datetime(2013, 10, 18, 0, 0)},
#  {u'cnt': 43, u'd': datetime.datetime(2013, 12, 23, 0, 0)},
#  {u'cnt': 125, u'd': datetime.datetime(2013, 11, 7, 0, 0)},
#  {u'cnt': 12, u'd': datetime.datetime(2013, 7, 7, 0, 0)},
#  {u'cnt': 140, u'd': datetime.datetime(2014, 1, 6, 0, 0)},
#  {u'cnt': 191, u'd': datetime.datetime(2013, 5, 8, 0, 0)},
#  {u'cnt': 167, u'd': datetime.datetime(2014, 1, 9, 0, 0)},
#  {u'cnt': 51, u'd': datetime.datetime(2013, 10, 21, 0, 0)},
#  {u'cnt': 40, u'd': datetime.datetime(2013, 9, 5, 0, 0)},
#  {u'cnt': 25, u'd': datetime.datetime(2013, 7, 4, 0, 0)},
#  {u'cnt': 112, u'd': datetime.datetime(2013, 9, 25, 0, 0)},
#  {u'cnt': 68, u'd': datetime.datetime(2013, 11, 10, 0, 0)},
#  {u'cnt': 17, u'd': datetime.datetime(2013, 5, 25, 0, 0)},
#  {u'cnt': 74, u'd': datetime.datetime(2014, 1, 26, 0, 0)},
#  {u'cnt': 15, u'd': datetime.datetime(2013, 7, 24, 0, 0)},
#  {u'cnt': 22, u'd': datetime.datetime(2013, 9, 8, 0, 0)},
#  {u'cnt': 67, u'd': datetime.datetime(2013, 5, 5, 0, 0)},
#  {u'cnt': 126, u'd': datetime.datetime(2013, 11, 27, 0, 0)},
#  {u'cnt': 115, u'd': datetime.datetime(2014, 1, 12, 0, 0)},
#  {u'cnt': 45, u'd': datetime.datetime(2013, 5, 22, 0, 0)},
#  {u'cnt': 92, u'd': datetime.datetime(2013, 5, 14, 0, 0)},
#  {u'cnt': 31, u'd': datetime.datetime(2013, 9, 14, 0, 0)},
#  {u'cnt': 86, u'd': datetime.datetime(2014, 1, 15, 0, 0)},
#  {u'cnt': 68, u'd': datetime.datetime(2013, 11, 13, 0, 0)},
#  {u'cnt': 60, u'd': datetime.datetime(2013, 12, 29, 0, 0)},
#  {u'cnt': 32, u'd': datetime.datetime(2013, 11, 16, 0, 0)},
#  {u'cnt': 8, u'd': datetime.datetime(2013, 7, 13, 0, 0)},
#  {u'cnt': 46, u'd': datetime.datetime(2013, 5, 11, 0, 0)},
#  {u'cnt': 28, u'd': datetime.datetime(2013, 6, 26, 0, 0)},
#  {u'cnt': 61, u'd': datetime.datetime(2013, 12, 3, 0, 0)},
#  {u'cnt': 38, u'd': datetime.datetime(2013, 10, 4, 0, 0)},
#  {u'cnt': 20, u'd': datetime.datetime(2013, 8, 2, 0, 0)},
#  {u'cnt': 52, u'd': datetime.datetime(2014, 1, 18, 0, 0)},
#  {u'cnt': 41, u'd': datetime.datetime(2013, 10, 1, 0, 0)},
#  {u'cnt': 18, u'd': datetime.datetime(2013, 5, 31, 0, 0)},
#  {u'cnt': 50, u'd': datetime.datetime(2013, 11, 19, 0, 0)},
#  {u'cnt': 122, u'd': datetime.datetime(2014, 2, 4, 0, 0)},
#  {u'cnt': 49, u'd': datetime.datetime(2013, 9, 17, 0, 0)},
#  {u'cnt': 125, u'd': datetime.datetime(2013, 7, 16, 0, 0)},
#  {u'cnt': 56, u'd': datetime.datetime(2013, 10, 7, 0, 0)},
#  {u'cnt': 87, u'd': datetime.datetime(2014, 2, 7, 0, 0)},
#  {u'cnt': 22, u'd': datetime.datetime(2013, 6, 20, 0, 0)},
#  {u'cnt': 23, u'd': datetime.datetime(2013, 8, 22, 0, 0)},
#  {u'cnt': 96, u'd': datetime.datetime(2013, 12, 6, 0, 0)},
#  {u'cnt': 19, u'd': datetime.datetime(2013, 8, 5, 0, 0)},
#  {u'cnt': 86, u'd': datetime.datetime(2013, 12, 9, 0, 0)},
#  {u'cnt': 27, u'd': datetime.datetime(2013, 6, 3, 0, 0)},
#  {u'cnt': 15, u'd': datetime.datetime(2013, 8, 25, 0, 0)},
#  {u'cnt': 69, u'd': datetime.datetime(2013, 9, 11, 0, 0)},
#  {u'cnt': 28, u'd': datetime.datetime(2013, 10, 27, 0, 0)},
#  {u'cnt': 50, u'd': datetime.datetime(2013, 12, 26, 0, 0)},
#  {u'cnt': 30, u'd': datetime.datetime(2013, 7, 10, 0, 0)},
#  {u'cnt': 39, u'd': datetime.datetime(2013, 10, 24, 0, 0)},
#  {u'cnt': 10, u'd': datetime.datetime(2013, 6, 23, 0, 0)},
#  {u'cnt': 16, u'd': datetime.datetime(2013, 6, 29, 0, 0)},
#  {u'cnt': 68, u'd': datetime.datetime(2013, 10, 30, 0, 0)},
#  {u'cnt': 105, u'd': datetime.datetime(2013, 8, 14, 0, 0)},
#  {u'cnt': 39, u'd': datetime.datetime(2013, 12, 15, 0, 0)},
#  {u'cnt': 34, u'd': datetime.datetime(2013, 10, 16, 0, 0)},
#  {u'cnt': 35, u'd': datetime.datetime(2014, 1, 1, 0, 0)},
#  {u'cnt': 23, u'd': datetime.datetime(2013, 6, 12, 0, 0)},
#  {u'cnt': 33, u'd': datetime.datetime(2013, 10, 13, 0, 0)},
#  {u'cnt': 193, u'd': datetime.datetime(2013, 8, 28, 0, 0)},
#  {u'cnt': 19, u'd': datetime.datetime(2013, 7, 19, 0, 0)},
#  {u'cnt': 18, u'd': datetime.datetime(2013, 5, 17, 0, 0)},
#  {u'cnt': 33, u'd': datetime.datetime(2013, 7, 2, 0, 0)},
#  {u'cnt': 30, u'd': datetime.datetime(2013, 9, 3, 0, 0)},
#  {u'cnt': 13, u'd': datetime.datetime(2013, 8, 31, 0, 0)},
#  {u'cnt': 157, u'd': datetime.datetime(2014, 1, 21, 0, 0)},
#  {u'cnt': 133, u'd': datetime.datetime(2014, 1, 4, 0, 0)},
#  {u'cnt': 30, u'd': datetime.datetime(2013, 11, 2, 0, 0)},
#  {u'cnt': 100, u'd': datetime.datetime(2014, 1, 7, 0, 0)},
#  {u'cnt': 40, u'd': datetime.datetime(2013, 6, 6, 0, 0)},
#  {u'cnt': 24, u'd': datetime.datetime(2013, 7, 22, 0, 0)},
#  {u'cnt': 48, u'd': datetime.datetime(2013, 11, 22, 0, 0)},
#  {u'cnt': 34, u'd': datetime.datetime(2013, 5, 20, 0, 0)},
#  {u'cnt': 152, u'd': datetime.datetime(2013, 11, 5, 0, 0)},
#  {u'cnt': 28, u'd': datetime.datetime(2013, 9, 20, 0, 0)},
#  {u'cnt': 61, u'd': datetime.datetime(2014, 1, 24, 0, 0)},
#  {u'cnt': 76, u'd': datetime.datetime(2013, 11, 25, 0, 0)},
#  {u'cnt': 96, u'd': datetime.datetime(2014, 1, 27, 0, 0)},
#  {u'cnt': 31, u'd': datetime.datetime(2013, 7, 25, 0, 0)},
#  {u'cnt': 18, u'd': datetime.datetime(2013, 6, 9, 0, 0)},
#  {u'cnt': 15, u'd': datetime.datetime(2013, 8, 11, 0, 0)},
#  {u'cnt': 110, u'd': datetime.datetime(2013, 9, 23, 0, 0)},
#  {u'cnt': 37, u'd': datetime.datetime(2013, 5, 23, 0, 0)},
#  {u'cnt': 57, u'd': datetime.datetime(2013, 12, 12, 0, 0)},
#  {u'cnt': 34, u'd': datetime.datetime(2013, 8, 8, 0, 0)},
#  {u'cnt': 81, u'd': datetime.datetime(2013, 10, 10, 0, 0)},
#  {u'cnt': 100, u'd': datetime.datetime(2014, 1, 30, 0, 0)},
#  {u'cnt': 32, u'd': datetime.datetime(2013, 9, 29, 0, 0)},
#  {u'cnt': 48, u'd': datetime.datetime(2013, 11, 14, 0, 0)},
#  {u'cnt': 41, u'd': datetime.datetime(2013, 5, 29, 0, 0)},
#  {u'cnt': 64, u'd': datetime.datetime(2013, 11, 28, 0, 0)},
#  {u'cnt': 101, u'd': datetime.datetime(2013, 9, 12, 0, 0)},
#  {u'cnt': 23, u'd': datetime.datetime(2013, 7, 28, 0, 0)},
#  {u'cnt': 45, u'd': datetime.datetime(2013, 12, 1, 0, 0)},
#  {u'cnt': 24, u'd': datetime.datetime(2013, 5, 26, 0, 0)},
#  {u'cnt': 25, u'd': datetime.datetime(2013, 10, 19, 0, 0)},
#  {u'cnt': 133, u'd': datetime.datetime(2013, 12, 18, 0, 0)},
#  {u'cnt': 152, u'd': datetime.datetime(2014, 2, 2, 0, 0)},
#  {u'cnt': 110, u'd': datetime.datetime(2014, 2, 5, 0, 0)},
#  {u'cnt': 35, u'd': datetime.datetime(2013, 12, 21, 0, 0)},
#  {u'cnt': 17, u'd': datetime.datetime(2013, 8, 17, 0, 0)},
#  {u'cnt': 44, u'd': datetime.datetime(2013, 10, 2, 0, 0)},
#  {u'cnt': 16, u'd': datetime.datetime(2013, 7, 31, 0, 0)},
#  {u'cnt': 15, u'd': datetime.datetime(2013, 6, 15, 0, 0)},
#  {u'cnt': 101, u'd': datetime.datetime(2013, 12, 4, 0, 0)},
#  {u'cnt': 15, u'd': datetime.datetime(2013, 9, 6, 0, 0)},
#  {u'cnt': 26, u'd': datetime.datetime(2013, 6, 21, 0, 0)},
#  {u'cnt': 68, u'd': datetime.datetime(2013, 11, 8, 0, 0)},
#  {u'cnt': 42, u'd': datetime.datetime(2013, 8, 20, 0, 0)},
#  {u'cnt': 64, u'd': datetime.datetime(2013, 5, 9, 0, 0)},
#  {u'cnt': 14, u'd': datetime.datetime(2013, 7, 5, 0, 0)},
#  {u'cnt': 45, u'd': datetime.datetime(2013, 12, 24, 0, 0)},
#  {u'cnt': 19, u'd': datetime.datetime(2013, 6, 18, 0, 0)},
#  {u'cnt': 48, u'd': datetime.datetime(2013, 10, 22, 0, 0)},
#  {u'cnt': 169, u'd': datetime.datetime(2013, 5, 3, 0, 0)},
#  {u'cnt': 28, u'd': datetime.datetime(2013, 7, 11, 0, 0)},
#  {u'cnt': 102, u'd': datetime.datetime(2014, 1, 10, 0, 0)},
#  {u'cnt': 65, u'd': datetime.datetime(2013, 9, 26, 0, 0)},
#  {u'cnt': 90, u'd': datetime.datetime(2014, 1, 13, 0, 0)},
#  {u'cnt': 118, u'd': datetime.datetime(2013, 9, 9, 0, 0)},
#  {u'cnt': 81, u'd': datetime.datetime(2013, 11, 11, 0, 0)},
#  {u'cnt': 195, u'd': datetime.datetime(2013, 5, 6, 0, 0)},
#  {u'cnt': 16, u'd': datetime.datetime(2013, 7, 8, 0, 0)},
#  {u'cnt': 57, u'd': datetime.datetime(2013, 12, 30, 0, 0)},
#  {u'cnt': 149, u'd': datetime.datetime(2013, 8, 29, 0, 0)},
#  {u'cnt': 44, u'd': datetime.datetime(2013, 10, 31, 0, 0)},
#  {u'cnt': 29, u'd': datetime.datetime(2013, 9, 15, 0, 0)},
#  {u'cnt': 6, u'd': datetime.datetime(2013, 7, 14, 0, 0)},
#  {u'cnt': 34, u'd': datetime.datetime(2013, 10, 28, 0, 0)},
#  {u'cnt': 44, u'd': datetime.datetime(2013, 5, 12, 0, 0)},
#  {u'cnt': 27, u'd': datetime.datetime(2013, 6, 27, 0, 0)},
#  {u'cnt': 94, u'd': datetime.datetime(2014, 1, 16, 0, 0)},
#  {u'cnt': 10, u'd': datetime.datetime(2013, 8, 3, 0, 0)},
#  {u'cnt': 63, u'd': datetime.datetime(2013, 9, 18, 0, 0)},
#  {u'cnt': 92, u'd': datetime.datetime(2014, 1, 19, 0, 0)},
#  {u'cnt': 36, u'd': datetime.datetime(2013, 11, 17, 0, 0)},
#  {u'cnt': 132, u'd': datetime.datetime(2014, 1, 2, 0, 0)},
#  {u'cnt': 14, u'd': datetime.datetime(2013, 6, 1, 0, 0)},
#  {u'cnt': 54, u'd': datetime.datetime(2013, 11, 20, 0, 0)},
#  {u'cnt': 56, u'd': datetime.datetime(2013, 7, 17, 0, 0)},
#  {u'cnt': 68, u'd': datetime.datetime(2013, 5, 15, 0, 0)},
#  {u'cnt': 61, u'd': datetime.datetime(2013, 12, 7, 0, 0)},
#  {u'cnt': 31, u'd': datetime.datetime(2013, 8, 6, 0, 0)},
#  {u'cnt': 60, u'd': datetime.datetime(2013, 10, 8, 0, 0)},
#  {u'cnt': 75, u'd': datetime.datetime(2014, 1, 22, 0, 0)},
#  {u'cnt': 31, u'd': datetime.datetime(2013, 10, 5, 0, 0)},
#  {u'cnt': 89, u'd': datetime.datetime(2013, 6, 4, 0, 0)},
#  {u'cnt': 69, u'd': datetime.datetime(2014, 2, 8, 0, 0)},
#  {u'cnt': 15, u'd': datetime.datetime(2013, 5, 18, 0, 0)},
#  {u'cnt': 46, u'd': datetime.datetime(2013, 10, 11, 0, 0)},
#  {u'cnt': 22, u'd': datetime.datetime(2013, 6, 24, 0, 0)},
#  {u'cnt': 88, u'd': datetime.datetime(2013, 12, 10, 0, 0)},
#  {u'cnt': 28, u'd': datetime.datetime(2013, 8, 26, 0, 0)},
#  {u'cnt': 28, u'd': datetime.datetime(2013, 8, 9, 0, 0)},
#  {u'cnt': 15, u'd': datetime.datetime(2013, 8, 23, 0, 0)},
#  {u'cnt': 20, u'd': datetime.datetime(2013, 6, 7, 0, 0)},
#  {u'cnt': 34, u'd': datetime.datetime(2013, 10, 25, 0, 0)},
#  {u'cnt': 66, u'd': datetime.datetime(2013, 12, 27, 0, 0)},
#  {u'cnt': 91, u'd': datetime.datetime(2013, 11, 29, 0, 0)},
#  {u'cnt': 43, u'd': datetime.datetime(2013, 8, 15, 0, 0)},
#  {u'cnt': 61, u'd': datetime.datetime(2013, 6, 13, 0, 0)},
#  {u'cnt': 28, u'd': datetime.datetime(2013, 8, 12, 0, 0)},
#  {u'cnt': 44, u'd': datetime.datetime(2013, 9, 27, 0, 0)},
#  {u'cnt': 479, u'd': datetime.datetime(2013, 5, 1, 0, 0)},
#  {u'cnt': 64, u'd': datetime.datetime(2014, 1, 31, 0, 0)},
#  {u'cnt': 109, u'd': datetime.datetime(2013, 12, 16, 0, 0)},
#  {u'cnt': 43, u'd': datetime.datetime(2013, 10, 14, 0, 0)},
#  {u'cnt': 30, u'd': datetime.datetime(2013, 7, 3, 0, 0)},
#  {u'cnt': 36, u'd': datetime.datetime(2013, 11, 3, 0, 0)},
#  {u'cnt': 79, u'd': datetime.datetime(2013, 12, 19, 0, 0)},
#  {u'cnt': 135, u'd': datetime.datetime(2014, 1, 5, 0, 0)},
#  {u'cnt': 22, u'd': datetime.datetime(2013, 6, 16, 0, 0)},
#  {u'cnt': 45, u'd': datetime.datetime(2013, 10, 17, 0, 0)},
#  {u'cnt': 35, u'd': datetime.datetime(2013, 6, 30, 0, 0)},
#  {u'cnt': 21, u'd': datetime.datetime(2013, 9, 1, 0, 0)},
#  {u'cnt': 47, u'd': datetime.datetime(2013, 5, 21, 0, 0)},
#  {u'cnt': 14, u'd': datetime.datetime(2013, 9, 7, 0, 0)},
#  {u'cnt': 10, u'd': datetime.datetime(2013, 7, 6, 0, 0)},
#  {u'cnt': 9, u'd': datetime.datetime(2013, 7, 20, 0, 0)},
#  {u'cnt': 49, u'd': datetime.datetime(2014, 1, 25, 0, 0)},
#  {u'cnt': 17, u'd': datetime.datetime(2013, 9, 4, 0, 0)},
#  {u'cnt': 36, u'd': datetime.datetime(2013, 11, 23, 0, 0)},
#  {u'cnt': 139, u'd': datetime.datetime(2014, 1, 8, 0, 0)},
#  {u'cnt': 340, u'd': datetime.datetime(2013, 11, 6, 0, 0)},
#  {u'cnt': 46, u'd': datetime.datetime(2013, 9, 21, 0, 0)},
#  {u'cnt': 15, u'd': datetime.datetime(2013, 7, 26, 0, 0)},
#  {u'cnt': 31, u'd': datetime.datetime(2013, 6, 10, 0, 0)},
#  {u'cnt': 124, u'd': datetime.datetime(2013, 5, 4, 0, 0)},
#  {u'cnt': 30, u'd': datetime.datetime(2013, 5, 24, 0, 0)},
#  {u'cnt': 103, u'd': datetime.datetime(2014, 1, 28, 0, 0)},
#  {u'cnt': 56, u'd': datetime.datetime(2013, 12, 13, 0, 0)},
#  {u'cnt': 16, u'd': datetime.datetime(2013, 7, 23, 0, 0)},
#  {u'cnt': 156, u'd': datetime.datetime(2013, 9, 24, 0, 0)},
#  {u'cnt': 103, u'd': datetime.datetime(2013, 11, 26, 0, 0)},
#  {u'cnt': 60, u'd': datetime.datetime(2013, 5, 13, 0, 0)},
#  {u'cnt': 51, u'd': datetime.datetime(2013, 9, 30, 0, 0)},
#  {u'cnt': 21, u'd': datetime.datetime(2013, 7, 29, 0, 0)},
#  {u'cnt': 129, u'd': datetime.datetime(2014, 1, 14, 0, 0)},
#  {u'cnt': 35, u'd': datetime.datetime(2013, 5, 27, 0, 0)},
#  {u'cnt': 72, u'd': datetime.datetime(2014, 1, 17, 0, 0)},
#  {u'cnt': 68, u'd': datetime.datetime(2013, 9, 13, 0, 0)},
#  {u'cnt': 40, u'd': datetime.datetime(2013, 11, 15, 0, 0)},
#  {u'cnt': 10, u'd': datetime.datetime(2013, 7, 12, 0, 0)},
#  {u'cnt': 21, u'd': datetime.datetime(2013, 8, 18, 0, 0)},
#  {u'cnt': 109, u'd': datetime.datetime(2014, 2, 3, 0, 0)},
#  {u'cnt': 44, u'd': datetime.datetime(2013, 10, 3, 0, 0)},
#  {u'cnt': 17, u'd': datetime.datetime(2013, 6, 2, 0, 0)},
#  {u'cnt': 33, u'd': datetime.datetime(2013, 10, 20, 0, 0)},
#  {u'cnt': 67, u'd': datetime.datetime(2013, 12, 2, 0, 0)},
#  {u'cnt': 27, u'd': datetime.datetime(2013, 8, 1, 0, 0)},
#  {u'cnt': 128, u'd': datetime.datetime(2013, 12, 5, 0, 0)},
#  {u'cnt': 23, u'd': datetime.datetime(2013, 5, 30, 0, 0)},
#  {u'cnt': 150, u'd': datetime.datetime(2013, 5, 7, 0, 0)},
#  {u'cnt': 66, u'd': datetime.datetime(2013, 10, 23, 0, 0)},
#  {u'cnt': 26, u'd': datetime.datetime(2013, 8, 21, 0, 0)},
#  {u'cnt': 97, u'd': datetime.datetime(2014, 2, 6, 0, 0)},
#  {u'cnt': 49, u'd': datetime.datetime(2013, 12, 22, 0, 0)},
#  {u'cnt': 33, u'd': datetime.datetime(2013, 12, 25, 0, 0)},
#  {u'cnt': 27, u'd': datetime.datetime(2013, 6, 19, 0, 0)},
#  {u'cnt': 7, u'd': datetime.datetime(2013, 8, 4, 0, 0)},
#  {u'cnt': 65, u'd': datetime.datetime(2013, 5, 10, 0, 0)},
#  {u'cnt': 137, u'd': datetime.datetime(2013, 9, 10, 0, 0)},
#  {u'cnt': 69, u'd': datetime.datetime(2014, 1, 11, 0, 0)},
#  {u'cnt': 24, u'd': datetime.datetime(2013, 10, 26, 0, 0)},
#  {u'cnt': 73, u'd': datetime.datetime(2013, 11, 12, 0, 0)},
#  {u'cnt': 60, u'd': datetime.datetime(2013, 12, 28, 0, 0)},
#  {u'cnt': 58, u'd': datetime.datetime(2013, 11, 9, 0, 0)},
#  {u'cnt': 13, u'd': datetime.datetime(2013, 7, 9, 0, 0)},
#  {u'cnt': 11, u'd': datetime.datetime(2013, 6, 22, 0, 0)},
#  {u'cnt': 10, u'd': datetime.datetime(2013, 8, 24, 0, 0)},
#  {u'cnt': 16, u'd': datetime.datetime(2013, 7, 15, 0, 0)},
#  {u'cnt': 20, u'd': datetime.datetime(2013, 6, 28, 0, 0)},
#  {u'cnt': 20, u'd': datetime.datetime(2013, 12, 14, 0, 0)},
#  {u'cnt': 23, u'd': datetime.datetime(2013, 8, 30, 0, 0)},
#  {u'cnt': 303, u'd': datetime.datetime(2013, 8, 27, 0, 0)},
#  {u'cnt': 131, u'd': datetime.datetime(2013, 10, 29, 0, 0)},
#  {u'cnt': 32, u'd': datetime.datetime(2013, 12, 31, 0, 0)},
#  {u'cnt': 62, u'd': datetime.datetime(2013, 11, 18, 0, 0)},
#  {u'cnt': 217, u'd': datetime.datetime(2014, 1, 3, 0, 0)},
#  {u'cnt': 460, u'd': datetime.datetime(2013, 9, 2, 0, 0)},
#  {u'cnt': 47, u'd': datetime.datetime(2013, 9, 19, 0, 0)},
#  {u'cnt': 17, u'd': datetime.datetime(2013, 7, 18, 0, 0)},
#  {u'cnt': 52, u'd': datetime.datetime(2013, 5, 16, 0, 0)},
#  {u'cnt': 66, u'd': datetime.datetime(2013, 7, 1, 0, 0)},
#  {u'cnt': 38, u'd': datetime.datetime(2013, 9, 16, 0, 0)},
#  {u'cnt': 36, u'd': datetime.datetime(2013, 11, 1, 0, 0)},
#  {u'cnt': 102, u'd': datetime.datetime(2014, 1, 20, 0, 0)},
#  {u'cnt': 32, u'd': datetime.datetime(2013, 8, 7, 0, 0)},
#  {u'cnt': 120, u'd': datetime.datetime(2014, 1, 23, 0, 0)},
#  {u'cnt': 46, u'd': datetime.datetime(2013, 11, 21, 0, 0)},
#  {u'cnt': 53, u'd': datetime.datetime(2013, 6, 5, 0, 0)},
#  {u'cnt': 10, u'd': datetime.datetime(2013, 7, 21, 0, 0)},
#  {u'cnt': 172, u'd': datetime.datetime(2013, 9, 22, 0, 0)},
#  {u'cnt': 57, u'd': datetime.datetime(2013, 11, 24, 0, 0)},
#  {u'cnt': 103, u'd': datetime.datetime(2014, 2, 9, 0, 0)},
#  {u'cnt': 15, u'd': datetime.datetime(2013, 5, 19, 0, 0)},
#  {u'cnt': 31, u'd': datetime.datetime(2013, 10, 6, 0, 0)},
#  {u'cnt': 70, u'd': datetime.datetime(2013, 12, 8, 0, 0)},
#  {u'cnt': 56, u'd': datetime.datetime(2013, 12, 11, 0, 0)},
#  {u'cnt': 26, u'd': datetime.datetime(2013, 6, 25, 0, 0)},
#  {u'cnt': 8, u'd': datetime.datetime(2013, 8, 10, 0, 0)},
#  {u'cnt': 29, u'd': datetime.datetime(2013, 10, 12, 0, 0)},
#  {u'cnt': 9, u'd': datetime.datetime(2013, 6, 8, 0, 0)},
#  {u'cnt': 160, u'd': datetime.datetime(2013, 10, 9, 0, 0)}]
